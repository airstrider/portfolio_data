# %% [markdown]
# # Exploratory data analysis
#
# This activity will examine data provided and prepare it for analysis.
# <br/>
#
# **The purpose** of this project is to conduct exploratory data analysis on a provided data set.
#
# **The goal** is to clean the data set and create a visualization.
# <br/>
# *This activity has 4 parts:*
#
# **Part 1:** Imports, links, and loading
#
# **Part 2:** Data Exploration
# *   Data cleaning
#
#
# **Part 3:** Building visualizations
#
# **Part 4:** Evaluate and share results

# %% [markdown]
# ### Part 1. Imports, links, and loading
# Go to Tableau Public
# The following link will help you complete this activity. Keep Tableau Public open as you proceed to the next steps.
#
# Link to supporting materials:
# Public Tableau: https://public.tableau.com/s/
#
# For EDA of the data, import the data and packages that would be most helpful, such as pandas, numpy and matplotlib.
#
# Then, import the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster

# %%
# Set an option to view all the columns
pd.set_option('display.max_columns',None)

# %% [markdown]
# Visit Data source location - https://data.baltimorecity.gov/datasets/baltimore::part-1-crime-data/explore?location=7.154814%2C-84.283614%2C3.60&showTable=true
#
# Click `Download` button to store `Part_1_Crime_Data.csv`, the csv format file, to your local.
#
# Load the source data

# %%
# crime_data = pd.read_csv('Part_1_Crime_Data.csv', low_memory=False)
crime_data = pd.read_csv('Part_1_Crime_Data.csv', low_memory=False, infer_datetime_format=True)

# %% [markdown]
# ### Part 2a. Data exploration and cleaning
#
# Decide which columns are applicable
#
# The first step is to assess your data.
# Check the Data Source page on Tableau Public to get a sense of the size, shape and makeup of the data set.
#
# These functions would help you simply understand and structure the data.
# *    `head()`
# *    `info()`

# %%
df0 = crime_data.copy()

# %%
df0
# Out:
#                 X          Y   RowID  CCNumber           CrimeDateTime  \
# 0      -76.601865  39.338840       1  12H11440  2012/08/23 15:20:00+00
# 1      -76.609580  39.289697       2  12H11175  2012/08/23 01:30:00+00
# 2      -76.605918  39.332891       3  12H12187  2012/08/23 22:00:00+00
# 3      -76.638263  39.301206       4  12H11606  2012/08/23 18:00:00+00
# 4      -76.574825  39.294108       5  12H11808  2012/08/23 17:00:00+00
# ...           ...        ...     ...       ...                     ...
# 581773 -76.600256  39.324805  581774  13E10616  2013/05/22 17:30:00+00
# 581774        NaN        NaN  581775  13E10311  2013/05/22 00:00:00+00
# 581775 -76.540956  39.315629  581776  13E10801  2013/05/22 16:00:00+00
# 581776 -76.587797  39.297575  581777  13E10531  2013/05/22 13:30:00+00
# 581777 -76.615807  39.300956  581778  13E10561  2013/05/22 16:45:00+00
#
#        CrimeCode        Description Inside_Outside Weapon Post Gender   Age  \
# 0             5B           BURGLARY              I    NaN  525      F  41.0
# 1             4E     COMMON ASSAULT              O    NaN  111      M  60.0
# 2             6D  LARCENY FROM AUTO              O    NaN  515      M  66.0
# 3             6J            LARCENY              I    NaN  724      F  29.0
# 4             7A         AUTO THEFT              O    NaN  222      U   NaN
# ...          ...                ...            ...    ...  ...    ...   ...
# 581773        4E     COMMON ASSAULT              I    NaN  411      F  13.0
# 581774        7A         AUTO THEFT              O    NaN  NaN      M  27.0
# 581775        5A           BURGLARY              I    NaN  443      M  22.0
# 581776        3B            ROBBERY              O    NaN  321      M  64.0
# 581777        6C            LARCENY              O    NaN  134    NaN   NaN
#
#                              Race Ethnicity              Location  \
# 0       BLACK_OR_AFRICAN_AMERICAN       NaN        900 ARGONNE DR
# 1                           WHITE       NaN    400 E BALTIMORE ST
# 2       BLACK_OR_AFRICAN_AMERICAN       NaN       700 MCKEWIN AVE
# 3       BLACK_OR_AFRICAN_AMERICAN       NaN        1200 RIGGS AVE
# 4                         UNKNOWN       NaN      100 N POTOMAC ST
# ...                           ...       ...                   ...
# 581773  BLACK_OR_AFRICAN_AMERICAN       NaN      1300 GORSUCH AVE
# 581774  BLACK_OR_AFRICAN_AMERICAN       NaN    1900 -BLK BOONE ST
# 581775  BLACK_OR_AFRICAN_AMERICAN       NaN  6000 MORAVIA PARK DR
# 581776  BLACK_OR_AFRICAN_AMERICAN       NaN     2100 MCELDERRY ST
# 581777                    UNKNOWN       NaN          0 E EAGER ST
#
#        Old_District New_District                     Neighborhood   Latitude  \
# 0          NORTHERN          NaN           EDNOR GARDENS-LAKESIDE  39.338840
# 1           CENTRAL          NaN                         DOWNTOWN  39.289697
# 2          NORTHERN          NaN                          WAVERLY  39.332891
# 3           WESTERN          NaN              SANDTOWN-WINCHESTER  39.301206
# 4         SOUTHEAST          NaN      PATTERSON PARK NEIGHBORHOOD  39.294108
# ...             ...          ...                              ...        ...
# 581773    NORTHEAST          NaN  COLDSTREAM HOMESTEAD MONTEBELLO  39.324805
# 581774          NaN          NaN                              NaN        NaN
# 581775    NORTHEAST          NaN                        FRANKFORD  39.315629
# 581776      EASTERN          NaN                             CARE  39.297575
# 581777      CENTRAL          NaN                     MOUNT VERNON  39.300956
#
#         Longitude                             GeoLocation  \
# 0      -76.601865                   (39.33884,-76.601865)
# 1      -76.609580                   (39.289697,-76.60958)
# 2      -76.605918                  (39.332891,-76.605918)
# 3      -76.638263                  (39.301206,-76.638263)
# 4      -76.574825                  (39.294108,-76.574825)
# ...           ...                                     ...
# 581773 -76.600256                  (39.324805,-76.600256)
# 581774        NaN                                     (,)
# 581775 -76.540956                  (39.315629,-76.540956)
# 581776 -76.587797  (39.29757463142731,-76.58779696079543)
# 581777 -76.615807                  (39.300956,-76.615807)
#
#                  PremiseType  Total_Incidents
# 0          ROW/TOWNHOUSE-OCC                1
# 1       STREET                              1
# 2       STREET                              1
# 3       APT/CONDO - OCCUPIED                1
# 4       STREET                              1
# ...                      ...              ...
# 581773  SCHOOL                              1
# 581774  STREET                              1
# 581775  APT/CONDO - OCCUPIED                1
# 581776  STREET                              1
# 581777  STREET                              1
#
# [581778 rows x 23 columns]

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581778 entries, 0 to 581777
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   X                580778 non-null  float64
#  1   Y                580778 non-null  float64
#  2   RowID            581778 non-null  int64
#  3   CCNumber         581478 non-null  object
#  4   CrimeDateTime    581778 non-null  object
#  5   CrimeCode        581778 non-null  object
#  6   Description      581778 non-null  object
#  7   Inside_Outside   448326 non-null  object
#  8   Weapon           143040 non-null  object
#  9   Post             572948 non-null  object
#  10  Gender           488159 non-null  object
#  11  Age              468208 non-null  float64
#  12  Race             563611 non-null  object
#  13  Ethnicity        55968 non-null   object
#  14  Location         578621 non-null  object
#  15  Old_District     565280 non-null  object
#  16  New_District     7746 non-null    object
#  17  Neighborhood     572848 non-null  object
#  18  Latitude         580778 non-null  float64
#  19  Longitude        580778 non-null  float64
#  20  GeoLocation      581778 non-null  object
#  21  PremiseType      447990 non-null  object
#  22  Total_Incidents  581778 non-null  int64
# dtypes: float64(5), int64(2), object(16)
# memory usage: 102.1+ MB

# %%
# There are some colums containing duplicate, `NaN` or insufficient data.
# Drop them to reduce the redundancy and save memory.
columns_to_drop = ['RowID', 'X', 'Y', 'GeoLocation', 'Ethnicity', 'New_District']
df1 = df0.drop(columns=columns_to_drop, axis=1)
df1.head()
# Out:
#    CCNumber           CrimeDateTime CrimeCode        Description  \
# 0  12H11440  2012/08/23 15:20:00+00        5B           BURGLARY
# 1  12H11175  2012/08/23 01:30:00+00        4E     COMMON ASSAULT
# 2  12H12187  2012/08/23 22:00:00+00        6D  LARCENY FROM AUTO
# 3  12H11606  2012/08/23 18:00:00+00        6J            LARCENY
# 4  12H11808  2012/08/23 17:00:00+00        7A         AUTO THEFT
#
#   Inside_Outside Weapon Post Gender   Age                       Race  \
# 0              I    NaN  525      F  41.0  BLACK_OR_AFRICAN_AMERICAN
# 1              O    NaN  111      M  60.0                      WHITE
# 2              O    NaN  515      M  66.0  BLACK_OR_AFRICAN_AMERICAN
# 3              I    NaN  724      F  29.0  BLACK_OR_AFRICAN_AMERICAN
# 4              O    NaN  222      U   NaN                    UNKNOWN
#
#              Location Old_District                 Neighborhood   Latitude  \
# 0      900 ARGONNE DR     NORTHERN       EDNOR GARDENS-LAKESIDE  39.338840
# 1  400 E BALTIMORE ST      CENTRAL                     DOWNTOWN  39.289697
# 2     700 MCKEWIN AVE     NORTHERN                      WAVERLY  39.332891
# 3      1200 RIGGS AVE      WESTERN          SANDTOWN-WINCHESTER  39.301206
# 4    100 N POTOMAC ST    SOUTHEAST  PATTERSON PARK NEIGHBORHOOD  39.294108
#
#    Longitude           PremiseType  Total_Incidents
# 0 -76.601865     ROW/TOWNHOUSE-OCC                1
# 1 -76.609580  STREET                              1
# 2 -76.605918  STREET                              1
# 3 -76.638263  APT/CONDO - OCCUPIED                1
# 4 -76.574825  STREET                              1

# %%
df1.dtypes
# Out:
# CCNumber            object
# CrimeDateTime       object
# CrimeCode           object
# Description         object
# Inside_Outside      object
# Weapon              object
# Post                object
# Gender              object
# Age                float64
# Race                object
# Location            object
# Old_District        object
# Neighborhood        object
# Latitude           float64
# Longitude          float64
# PremiseType         object
# Total_Incidents      int64
# dtype: object

# %% [markdown]
# ### Part 2b. Data extraction
#
# Decide which data need to be focused

# %%
# Check `Weapon` type
df1['Weapon'].value_counts()
# Out:
# FIREARM                           47570
# OTHER                             30818
# PERSONAL_WEAPONS                  25719
# KNIFE                             17226
# HANDS                              6969
# HANDGUN                            5396
# KNIFE_CUTTING_INSTRUMENT           2971
# FIRE                               2264
# BLUNT_OBJECT                       2019
# UNKNOWN                             929
# MOTOR_VEHICLE_VESSEL                384
# AUTOMATIC_HANDGUN                   182
# ASPHYXIATION                        115
# OTHER_FIREARM                       109
# RIFLE                                87
# FIRE_INCENDIARY_DEVICE               80
# SHOTGUN                              76
# AUTOMATIC_FIREARM                    72
# AUTOMATIC_RIFLE                      23
# POISON                               18
# DRUGS_NARCOTICS_SLEEPING_PILLS        6
# EXPLOSIVES                            4
# AUTOMATIC_SHOTGUN                     3
# Name: Weapon, dtype: int64

# %% [markdown]
# Filter the records that 'Weapon' contains `GUN`, `RIFLE` or `SHOTGUN`.
#
# `FIREARM` type weapon is excluded.

# %%
weapon_type_gun = ['HANDGUN','RIFLE','SHOTGUN','AUTOMATIC_HANDGUN','AUTOMATIC_RIFLE','AUTOMATIC_SHOTGUN']
df1 = df1[df1['Weapon'].isin(weapon_type_gun)]
df1
# Out:
#         CCNumber             CrimeDateTime CrimeCode   Description  \
# 60      23H03990 2023-08-11 16:39:00+00:00        1A      HOMICIDE
# 99      23H06485 2023-08-18 05:54:00+00:00        9S      SHOOTING
# 146     23H06851 2023-08-19 04:45:00+00:00        4A  AGG. ASSAULT
# 211     23H06729 2023-08-18 18:40:00+00:00       3AF       ROBBERY
# 212     23H06729 2023-08-18 18:40:00+00:00       3AF       ROBBERY
# ...          ...                       ...       ...           ...
# 121062  23G02462 2023-07-08 04:35:00+00:00       3AF       ROBBERY
# 121066  23G02680 2023-07-08 20:00:00+00:00        5A      BURGLARY
# 121136  23G02450 2023-07-08 02:56:00+00:00        4A  AGG. ASSAULT
# 121810  23G04865 2023-07-15 01:05:00+00:00        4A  AGG. ASSAULT
# 453288  22I08945 2007-09-26 22:00:00+00:00        4B  AGG. ASSAULT
#
#        Inside_Outside   Weapon Post Gender   Age                       Race  \
# 60             Inside  HANDGUN  421      M  18.0  BLACK_OR_AFRICAN_AMERICAN
# 99             Inside  HANDGUN  633      F  33.0  BLACK_OR_AFRICAN_AMERICAN
# 146           Outside  HANDGUN  615      F  26.0  BLACK_OR_AFRICAN_AMERICAN
# 211            Inside  HANDGUN  414      M  22.0  BLACK_OR_AFRICAN_AMERICAN
# 212            Inside  HANDGUN  414      F  33.0  BLACK_OR_AFRICAN_AMERICAN
# ...               ...      ...  ...    ...   ...                        ...
# 121062            NaN  HANDGUN  414      M  64.0  BLACK_OR_AFRICAN_AMERICAN
# 121066            NaN  HANDGUN  724      M  34.0  BLACK_OR_AFRICAN_AMERICAN
# 121136            NaN  HANDGUN  313      M  20.0  BLACK_OR_AFRICAN_AMERICAN
# 121810         Inside  HANDGUN  324      F  37.0                      WHITE
# 453288            NaN  HANDGUN  314      F  43.0  BLACK_OR_AFRICAN_AMERICAN
#
#                     Location Old_District                Neighborhood  \
# 60            1800 E 33rd St          NaN                  MONTEBELLO
# 99         5200 FAIRLAWN AVE          NaN                    WOODMERE
# 146        2900 PRESSTMAN ST          NaN  NORTHWEST COMMUNITY ACTION
# 211     6100 CHINQUAPIN PKWY          NaN                   GLEN OAKS
# 212     6100 CHINQUAPIN PKWY          NaN                   GLEN OAKS
# ...                      ...          ...                         ...
# 121062     5600 WOODMONT AVE    NORTHEAST          WOODBOURNE HEIGHTS
# 121066     900 N STRICKER ST      WESTERN         SANDTOWN-WINCHESTER
# 121136        500 E EAGER ST      EASTERN             JOHNSTON SQUARE
# 121810     3000 E FEDERAL ST          NaN                       BEREA
# 453288       1700 LAMONT AVE      EASTERN                      OLIVER
#
#          Latitude  Longitude        PremiseType  Total_Incidents
# 60      39.328515 -76.589042             STREET                1
# 99      39.342229 -76.684559             STREET                1
# 146     39.304616 -76.666256  OTHER/RESIDENTIAL                1
# 211     39.367111 -76.598880             STREET                1
# 212     39.367111 -76.598880             STREET                1
# ...           ...        ...                ...              ...
# 121062  39.356677 -76.590771                NaN                1
# 121066  39.299034 -76.641618                NaN                1
# 121136  39.301341 -76.609006                NaN                1
# 121810  39.309284 -76.575798             STREET                1
# 453288  39.309633 -76.602557                NaN                1
#
# [5767 rows x 17 columns]

# %% [markdown]
# ### Part 2c. Data conversion
#
# Convert object type data into proper type data for the purpose.
#
# Convert data type of `CrimeDateTime` from `object` to `timestamp`

# %%
df1['CrimeDateTime'] = pd.to_datetime(df1['CrimeDateTime'])
df1
# Out:
#         CCNumber             CrimeDateTime CrimeCode   Description  \
# 60      23H03990 2023-08-11 16:39:00+00:00        1A      HOMICIDE
# 99      23H06485 2023-08-18 05:54:00+00:00        9S      SHOOTING
# 146     23H06851 2023-08-19 04:45:00+00:00        4A  AGG. ASSAULT
# 211     23H06729 2023-08-18 18:40:00+00:00       3AF       ROBBERY
# 212     23H06729 2023-08-18 18:40:00+00:00       3AF       ROBBERY
# ...          ...                       ...       ...           ...
# 121062  23G02462 2023-07-08 04:35:00+00:00       3AF       ROBBERY
# 121066  23G02680 2023-07-08 20:00:00+00:00        5A      BURGLARY
# 121136  23G02450 2023-07-08 02:56:00+00:00        4A  AGG. ASSAULT
# 121810  23G04865 2023-07-15 01:05:00+00:00        4A  AGG. ASSAULT
# 453288  22I08945 2007-09-26 22:00:00+00:00        4B  AGG. ASSAULT
#
#        Inside_Outside   Weapon Post Gender   Age                       Race  \
# 60             Inside  HANDGUN  421      M  18.0  BLACK_OR_AFRICAN_AMERICAN
# 99             Inside  HANDGUN  633      F  33.0  BLACK_OR_AFRICAN_AMERICAN
# 146           Outside  HANDGUN  615      F  26.0  BLACK_OR_AFRICAN_AMERICAN
# 211            Inside  HANDGUN  414      M  22.0  BLACK_OR_AFRICAN_AMERICAN
# 212            Inside  HANDGUN  414      F  33.0  BLACK_OR_AFRICAN_AMERICAN
# ...               ...      ...  ...    ...   ...                        ...
# 121062            NaN  HANDGUN  414      M  64.0  BLACK_OR_AFRICAN_AMERICAN
# 121066            NaN  HANDGUN  724      M  34.0  BLACK_OR_AFRICAN_AMERICAN
# 121136            NaN  HANDGUN  313      M  20.0  BLACK_OR_AFRICAN_AMERICAN
# 121810         Inside  HANDGUN  324      F  37.0                      WHITE
# 453288            NaN  HANDGUN  314      F  43.0  BLACK_OR_AFRICAN_AMERICAN
#
#                     Location Old_District                Neighborhood  \
# 60            1800 E 33rd St          NaN                  MONTEBELLO
# 99         5200 FAIRLAWN AVE          NaN                    WOODMERE
# 146        2900 PRESSTMAN ST          NaN  NORTHWEST COMMUNITY ACTION
# 211     6100 CHINQUAPIN PKWY          NaN                   GLEN OAKS
# 212     6100 CHINQUAPIN PKWY          NaN                   GLEN OAKS
# ...                      ...          ...                         ...
# 121062     5600 WOODMONT AVE    NORTHEAST          WOODBOURNE HEIGHTS
# 121066     900 N STRICKER ST      WESTERN         SANDTOWN-WINCHESTER
# 121136        500 E EAGER ST      EASTERN             JOHNSTON SQUARE
# 121810     3000 E FEDERAL ST          NaN                       BEREA
# 453288       1700 LAMONT AVE      EASTERN                      OLIVER
#
#          Latitude  Longitude        PremiseType  Total_Incidents
# 60      39.328515 -76.589042             STREET                1
# 99      39.342229 -76.684559             STREET                1
# 146     39.304616 -76.666256  OTHER/RESIDENTIAL                1
# 211     39.367111 -76.598880             STREET                1
# 212     39.367111 -76.598880             STREET                1
# ...           ...        ...                ...              ...
# 121062  39.356677 -76.590771                NaN                1
# 121066  39.299034 -76.641618                NaN                1
# 121136  39.301341 -76.609006                NaN                1
# 121810  39.309284 -76.575798             STREET                1
# 453288  39.309633 -76.602557                NaN                1
#
# [5767 rows x 17 columns]

# %%
# Check the data type of `CrimeDateTime` data
df1.dtypes
# Out:
# CCNumber                        object
# CrimeDateTime      datetime64[ns, UTC]
# CrimeCode                       object
# Description                     object
# Inside_Outside                  object
# Weapon                          object
# Post                            object
# Gender                          object
# Age                            float64
# Race                            object
# Location                        object
# Old_District                    object
# Neighborhood                    object
# Latitude                       float64
# Longitude                      float64
# PremiseType                     object
# Total_Incidents                  int64
# dtype: object

# %% [markdown]
# ### Part 2d. Data cleaning
#
# Review null value data and decide whether they need to be removed or kept.
#
# Focus on `Latitude` and `Longitude` columns

# %%
# Check null values in the records
df1.isna().sum()
# Out:
# CCNumber              0
# CrimeDateTime         0
# CrimeCode             0
# Description           0
# Inside_Outside     5279
# Weapon                0
# Post                 82
# Gender              430
# Age                 465
# Race                787
# Location             47
# Old_District        550
# Neighborhood         82
# Latitude             11
# Longitude            11
# PremiseType        5279
# Total_Incidents       0
# dtype: int64

# %% [markdown]
# There are some records with null values.
#
# The goal of this work is to render the location of the gun violence on the `Baltimore City` map
#
# and to review the detail information on each violence.
#
# For these reasons, `Latitude` and `Longitude` records should `NOT` be `null`.
#
# But, 11 `null` records are found by `isna().sum()` command.
#
# Let's drop the records with null `Latitude` and `Longitude`.

# %%
df2 = df1.dropna(subset=['Latitude', 'Longitude'], axis=0).reset_index(drop=True)
# check null values in the records
df2.isna().sum()
# Out:
# CCNumber              0
# CrimeDateTime         0
# CrimeCode             0
# Description           0
# Inside_Outside     5272
# Weapon                0
# Post                 71
# Gender              430
# Age                 465
# Race                786
# Location             38
# Old_District        539
# Neighborhood         71
# Latitude              0
# Longitude             0
# PremiseType        5272
# Total_Incidents       0
# dtype: int64

# %%
df2
# Out:
#       CCNumber             CrimeDateTime CrimeCode   Description  \
# 0     23H03990 2023-08-11 16:39:00+00:00        1A      HOMICIDE
# 1     23H06485 2023-08-18 05:54:00+00:00        9S      SHOOTING
# 2     23H06851 2023-08-19 04:45:00+00:00        4A  AGG. ASSAULT
# 3     23H06729 2023-08-18 18:40:00+00:00       3AF       ROBBERY
# 4     23H06729 2023-08-18 18:40:00+00:00       3AF       ROBBERY
# ...        ...                       ...       ...           ...
# 5751  23G02462 2023-07-08 04:35:00+00:00       3AF       ROBBERY
# 5752  23G02680 2023-07-08 20:00:00+00:00        5A      BURGLARY
# 5753  23G02450 2023-07-08 02:56:00+00:00        4A  AGG. ASSAULT
# 5754  23G04865 2023-07-15 01:05:00+00:00        4A  AGG. ASSAULT
# 5755  22I08945 2007-09-26 22:00:00+00:00        4B  AGG. ASSAULT
#
#      Inside_Outside   Weapon Post Gender   Age                       Race  \
# 0            Inside  HANDGUN  421      M  18.0  BLACK_OR_AFRICAN_AMERICAN
# 1            Inside  HANDGUN  633      F  33.0  BLACK_OR_AFRICAN_AMERICAN
# 2           Outside  HANDGUN  615      F  26.0  BLACK_OR_AFRICAN_AMERICAN
# 3            Inside  HANDGUN  414      M  22.0  BLACK_OR_AFRICAN_AMERICAN
# 4            Inside  HANDGUN  414      F  33.0  BLACK_OR_AFRICAN_AMERICAN
# ...             ...      ...  ...    ...   ...                        ...
# 5751            NaN  HANDGUN  414      M  64.0  BLACK_OR_AFRICAN_AMERICAN
# 5752            NaN  HANDGUN  724      M  34.0  BLACK_OR_AFRICAN_AMERICAN
# 5753            NaN  HANDGUN  313      M  20.0  BLACK_OR_AFRICAN_AMERICAN
# 5754         Inside  HANDGUN  324      F  37.0                      WHITE
# 5755            NaN  HANDGUN  314      F  43.0  BLACK_OR_AFRICAN_AMERICAN
#
#                   Location Old_District                Neighborhood  \
# 0           1800 E 33rd St          NaN                  MONTEBELLO
# 1        5200 FAIRLAWN AVE          NaN                    WOODMERE
# 2        2900 PRESSTMAN ST          NaN  NORTHWEST COMMUNITY ACTION
# 3     6100 CHINQUAPIN PKWY          NaN                   GLEN OAKS
# 4     6100 CHINQUAPIN PKWY          NaN                   GLEN OAKS
# ...                    ...          ...                         ...
# 5751     5600 WOODMONT AVE    NORTHEAST          WOODBOURNE HEIGHTS
# 5752     900 N STRICKER ST      WESTERN         SANDTOWN-WINCHESTER
# 5753        500 E EAGER ST      EASTERN             JOHNSTON SQUARE
# 5754     3000 E FEDERAL ST          NaN                       BEREA
# 5755       1700 LAMONT AVE      EASTERN                      OLIVER
#
#        Latitude  Longitude        PremiseType  Total_Incidents
# 0     39.328515 -76.589042             STREET                1
# 1     39.342229 -76.684559             STREET                1
# 2     39.304616 -76.666256  OTHER/RESIDENTIAL                1
# 3     39.367111 -76.598880             STREET                1
# 4     39.367111 -76.598880             STREET                1
# ...         ...        ...                ...              ...
# 5751  39.356677 -76.590771                NaN                1
# 5752  39.299034 -76.641618                NaN                1
# 5753  39.301341 -76.609006                NaN                1
# 5754  39.309284 -76.575798             STREET                1
# 5755  39.309633 -76.602557                NaN                1
#
# [5756 rows x 17 columns]

# %% [markdown]
# The total number of records has been decreased from `5767` to `5756`
#
# For the convinience,
#
# extract the only `year 2023` records, allowing us to handle them in an easy way for the portotype map rendering work.

# %%
df_2023 = df2[df2['CrimeDateTime'].dt.year > 2022]
df_2023
# Out:
#       CCNumber             CrimeDateTime CrimeCode   Description  \
# 0     23H03990 2023-08-11 16:39:00+00:00        1A      HOMICIDE
# 1     23H06485 2023-08-18 05:54:00+00:00        9S      SHOOTING
# 2     23H06851 2023-08-19 04:45:00+00:00        4A  AGG. ASSAULT
# 3     23H06729 2023-08-18 18:40:00+00:00       3AF       ROBBERY
# 4     23H06729 2023-08-18 18:40:00+00:00       3AF       ROBBERY
# ...        ...                       ...       ...           ...
# 5750  23G02567 2023-07-08 04:45:00+00:00       3AF       ROBBERY
# 5751  23G02462 2023-07-08 04:35:00+00:00       3AF       ROBBERY
# 5752  23G02680 2023-07-08 20:00:00+00:00        5A      BURGLARY
# 5753  23G02450 2023-07-08 02:56:00+00:00        4A  AGG. ASSAULT
# 5754  23G04865 2023-07-15 01:05:00+00:00        4A  AGG. ASSAULT
#
#      Inside_Outside   Weapon Post Gender   Age                       Race  \
# 0            Inside  HANDGUN  421      M  18.0  BLACK_OR_AFRICAN_AMERICAN
# 1            Inside  HANDGUN  633      F  33.0  BLACK_OR_AFRICAN_AMERICAN
# 2           Outside  HANDGUN  615      F  26.0  BLACK_OR_AFRICAN_AMERICAN
# 3            Inside  HANDGUN  414      M  22.0  BLACK_OR_AFRICAN_AMERICAN
# 4            Inside  HANDGUN  414      F  33.0  BLACK_OR_AFRICAN_AMERICAN
# ...             ...      ...  ...    ...   ...                        ...
# 5750            NaN  HANDGUN  413      M  62.0  BLACK_OR_AFRICAN_AMERICAN
# 5751            NaN  HANDGUN  414      M  64.0  BLACK_OR_AFRICAN_AMERICAN
# 5752            NaN  HANDGUN  724      M  34.0  BLACK_OR_AFRICAN_AMERICAN
# 5753            NaN  HANDGUN  313      M  20.0  BLACK_OR_AFRICAN_AMERICAN
# 5754         Inside  HANDGUN  324      F  37.0                      WHITE
#
#                    Location Old_District                Neighborhood  \
# 0            1800 E 33rd St          NaN                  MONTEBELLO
# 1         5200 FAIRLAWN AVE          NaN                    WOODMERE
# 2         2900 PRESSTMAN ST          NaN  NORTHWEST COMMUNITY ACTION
# 3      6100 CHINQUAPIN PKWY          NaN                   GLEN OAKS
# 4      6100 CHINQUAPIN PKWY          NaN                   GLEN OAKS
# ...                     ...          ...                         ...
# 5750  1100 E COLD SPRING LN    NORTHEAST               NEW NORTHWOOD
# 5751      5600 WOODMONT AVE    NORTHEAST          WOODBOURNE HEIGHTS
# 5752      900 N STRICKER ST      WESTERN         SANDTOWN-WINCHESTER
# 5753         500 E EAGER ST      EASTERN             JOHNSTON SQUARE
# 5754      3000 E FEDERAL ST          NaN                       BEREA
#
#        Latitude  Longitude        PremiseType  Total_Incidents
# 0     39.328515 -76.589042             STREET                1
# 1     39.342229 -76.684559             STREET                1
# 2     39.304616 -76.666256  OTHER/RESIDENTIAL                1
# 3     39.367111 -76.598880             STREET                1
# 4     39.367111 -76.598880             STREET                1
# ...         ...        ...                ...              ...
# 5750  39.345129 -76.599069                NaN                1
# 5751  39.356677 -76.590771                NaN                1
# 5752  39.299034 -76.641618                NaN                1
# 5753  39.301341 -76.609006                NaN                1
# 5754  39.309284 -76.575798             STREET                1
#
# [1796 rows x 17 columns]

# %% [markdown]
# ### Part 3. Building Visualizations
#
# Use `folium` to render the location data to the `Baltimore City` map.

# %% [markdown]
# #### Part 3a. Preparation
#
# Get the mean of latitude and longitude to get the center point of the map.

# %%
lat  = df_2023['Latitude'].mean()
long = df_2023['Longitude'].mean()
lat, long
# Out:
# (39.264060735861506, -76.53010302768271)

# %% [markdown]
# #### Part 3b. Creating a color pick function
#
# Implement a function to map weapon type onto color.
#
# According to `folium document`, color icons should one of the following colors:
#
# `beige`, `black`, `blue`, `cadetblue`, `gray`, `green`, `orange`, `pink`, `purple`, `red`, `white`,
#
# `darkblue`, `darkgreen`, `darkpurple`, `darkred`, `lightblue`, `lightgray`, `lightgreen`, `lightred`

# %%
def weapon_mapper(index):
    if df_2023.loc[index, 'Weapon'] == 'HANDGUN':
        color = "orange"
    elif df_2023.loc[index, 'Weapon'] == 'RIFLE':
        color = "blue"
    elif df_2023.loc[index, 'Weapon'] == 'SHOTGUN':
        color = "green"
    elif df_2023.loc[index, 'Weapon'] == 'AUTOMATIC_HANDGUN':
        color = "pink"
    elif df_2023.loc[index, 'Weapon'] == 'AUTOMATIC_RIFLE':
        color = "purple"
    else:
        color = "red"

    return color

# %% [markdown]
# #### Part 3c. Rendering the map
#
# Map the data onto the `Baltimore City` map.

# %%
figure = folium.Figure(width='70%', height=None)
map_balt = folium.Map([lat, long], zoom_start=11).add_to(figure)
marker_cluster = MarkerCluster().add_to(map_balt)

for i in df_2023.index:
    sub_lat =  df_2023.loc[i, 'Latitude']
    sub_long = df_2023.loc[i, 'Longitude']
    color = weapon_mapper(i)
    tip=f"""
        Type: {df_2023.loc[i,'Weapon']}<br/>
        Loca: {df_2023.loc[i,'Location']}<br/>
        Date: {df_2023.loc[i,'CrimeDateTime']}
        """
    folium.Marker(
        location=[sub_lat, sub_long],
        icon=folium.Icon(color=color),
        tooltip=tip
    ).add_to(marker_cluster)

map_balt
# Out:
# <div style="width:70%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d500282307fcdddc7b640e95fe2c0ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d500282307fcdddc7b640e95fe2c0ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d500282307fcdddc7b640e95fe2c0ff = L.map(
#                 &quot;map_2d500282307fcdddc7b640e95fe2c0ff&quot;,
#                 {
#                     center: [39.264060735861506, -76.53010302768271],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae686886371feb78f2fd9c78e725b8c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2d500282307fcdddc7b640e95fe2c0ff);
#
#
#             var marker_cluster_738155a7e03e22a908457211ae3edca9 = L.markerClusterGroup(
#                 {}
#             );
#             map_2d500282307fcdddc7b640e95fe2c0ff.addLayer(marker_cluster_738155a7e03e22a908457211ae3edca9);
#
#
#             var marker_f8a3d6dc360945fa3ced94dd3cd9de4b = L.marker(
#                 [39.328515234182646, -76.58904220052153],
#                 {}
#             ).addTo(marker_cluster_738155a7e03e22a908457211ae3edca9);
#
#
#             var icon_64b47f290a125799e2716db664c81dfd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f8a3d6dc360945fa3ced94dd3cd9de4b.setIcon(icon_64b47f290a125799e2716db664c81dfd);
#
#
#             marker_f8a3d6dc360945fa3ced94dd3cd9de4b.bindTooltip(
#                 `&lt;div&gt;
#
#         Type: HANDGUN&lt;br/&gt;
#         Loca: 1800 E 33rd St&lt;br/&gt;
#         Date: 2023-08-11 16:39:00+00:00
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8ebd4c1a9373ccfedf05bbcab1044e2c = L.marker(
#                 [39.342229, -76.68455899999998],
#                 {}
#             ).addTo(marker_cluster_738155a7e03e22a908457211ae3edca9);
#
#
#             var icon_e77a7bc2856ee5d748fdd127a86eabcb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8ebd4c1a9373ccfedf05bbcab1044e2c.setIcon(icon_e77a7bc2856ee5d748fdd127a86eabcb);
#
#
#             marker_8ebd4c1a9373ccfedf05bbcab1044e2c.bindTooltip(
#                 `&lt;div&gt;
#
#         Type: HANDGUN&lt;br/&gt;
#         Loca: 5200 FAIRLAWN AVE&lt;br/&gt;
#         Date: 2023-08-18 05:54:00+00:00
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3912c3a71e5ab489d05818e09c462146 = L.marker(
#                 [39.304616, -76.666256],
#                 {}
#             ).addTo(marker_cluster_738155a7e03e22a908457211ae3edca9);
#
#
#             var icon_b09987f83afe684492940798e4758581 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3912c3a71e5ab489d05818e09c462146.setIcon(icon_b09987f83afe684492940798e4758581);
#
#
#             marker_3912c3a71e5ab489d05818e09c462146.bindTooltip(
#                 `&lt;div&gt;
#
#         Type: HANDGUN&lt;br/&gt;
#         Loca: 2900 PRESSTMAN ST&lt;br/&gt;
#         Date: 2023-08-19 04:45:00+00:00
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eb93ed8e7f194505369be82ee465e69e = L.marker(
#                 [39.367111, -76.59887999999998],
#                 {}
#             ).addTo(marker_cluster_738155a7e03e22a908457211ae3edca9);
#
#
#             var icon_6324e978798d335495299413d8a86cd0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &qu
